# %%
msg = "hellow world"
print(msg)
# Out:
# hellow world

# %%
# !python -m venv labenv
# Activate the virtual environment
# %pip install --upgrade typing-extensions
# %pip install python-dotenv azure-identity azure-ai-projects azure-ai-inference
# Out:
# Requirement already satisfied: typing-extensions in c:\users\mofaizal\appdata\local\programs\python\python313\lib\site-packages (4.13.2)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: python-dotenv in c:\users\mofaizal\appdata\local\programs\python\python313\lib\site-packages (1.1.0)
# Requirement already satisfied: azure-identity in c:\users\mofaizal\appdata\local\programs\python\python313\lib\site-packages (1.21.0)
# Requirement already satisfied: azure-ai-projects in c:\users\mofaizal\appdata\local\programs\python\python313\lib\site-packages (1.0.0b10)
# Requirement already satisfied: azure-ai-inference in c:\users\mofaizal\appdata\local\programs\python\python313\lib\site-packages (1.0.0b9)
# Requirement already satisfied: azure-core>=1.31.0 in c:\users\mofaizal\appdata\local\programs\python\python313\lib\site-packages (from azure-identity) (1.33.0)
# Requirement already satisfied: cryptography>=2.5 in c:\users\mofaizal\appdata\local\programs\python\python313\lib\site-packages (from azure-identity) (44.0.2)
# Requirement already satisfied: msal>=1.30.0 in c:\users\mofaizal\appdata\local\programs\python\python313\lib\site-packages (from azure-identity) (1.32.3)
# Requirement already satisfied: msal-extensions>=1.2.0 in c:\users\mofaizal\appdata\local\programs\python\python313\lib\site-packages (from azure-identity) (1.3.1)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\mofaizal\appdata\local\programs\python\python313\lib\site-packages (from azure-identity) (4.13.2)
# Requirement already satisfied: isodate>=0.6.1 in c:\users\mofaizal\appdata\local\programs\python\python313\lib\site-packages (from azure-ai-projects) (0.7.2)
# Requirement already satisfied: requests>=2.21.0 in c:\users\mofaizal\appdata\local\programs\python\python313\lib\site-packages (from azure-core>=1.31.0->azure-identity) (2.32.3)
# Requirement already satisfied: six>=1.11.0 in c:\users\mofaizal\appdata\local\programs\python\python313\lib\site-packages (from azure-core>=1.31.0->azure-identity) (1.17.0)
# Requirement already satisfied: cffi>=1.12 in c:\users\mofaizal\appdata\local\programs\python\python313\lib\site-packages (from cryptography>=2.5->azure-identity) (1.17.1)
# Requirement already satisfied: pycparser in c:\users\mofaizal\appdata\local\programs\python\python313\lib\site-packages (from cffi>=1.12->cryptography>=2.5->azure-identity) (2.22)
# Requirement already satisfied: PyJWT<3,>=1.0.0 in c:\users\mofaizal\appdata\local\programs\python\python313\lib\site-packages (from PyJWT[crypto]<3,>=1.0.0->msal>=1.30.0->azure-identity) (2.10.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\mofaizal\appdata\local\programs\python\python313\lib\site-packages (from requests>=2.21.0->azure-core>=1.31.0->azure-identity) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\mofaizal\appdata\local\programs\python\python313\lib\site-packages (from requests>=2.21.0->azure-core>=1.31.0->azure-identity) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\mofaizal\appdata\local\programs\python\python313\lib\site-packages (from requests>=2.21.0->azure-core>=1.31.0->azure-identity) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\mofaizal\appdata\local\programs\python\python313\lib\site-packages (from requests>=2.21.0->azure-core>=1.31.0->azure-identity) (2025.4.26)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os

# Add references
from dotenv import load_dotenv
from azure.identity import DefaultAzureCredential
from azure.ai.projects import AIProjectClient
from azure.ai.inference.models import SystemMessage, UserMessage, AssistantMessage


def main(): 

    # Clear the console
    os.system('cls' if os.name=='nt' else 'clear')
        
    try: 
    
        # Get configuration settings 
        load_dotenv()
        project_connection = os.getenv("PROJECT_CONNECTION")
        model_deployment =  os.getenv("MODEL_DEPLOYMENT")
        
        # Initialize the project client
        projectClient = AIProjectClient.from_connection_string(
            conn_str=project_connection,
            credential=DefaultAzureCredential())

        ## Get a chat client 
        chat = projectClient.inference.get_chat_completions_client()

        ## Initialize prompt with system message
        prompt=[
                SystemMessage("You are a helpful AI assistant that answers questions.")
           ]

        # Loop until the user types 'quit'
        while True:
            # Get input text
            input_text = input("Enter the prompt (or type 'quit' to exit): ")
            if input_text.lower() == "quit":
                break
            if len(input_text) == 0:
                print("Please enter a prompt.")
                continue
            
            # Get a chat completion
            prompt.append(UserMessage(input_text))
            response = chat.complete(
                model=model_deployment,
                messages=prompt)
            completion = response.choices[0].message.content
            print(completion)
            prompt.append(AssistantMessage(completion))

    except Exception as ex:
        print(ex)

if __name__ == '__main__': 
    main()
# Out:
# Singapore may be a small city-state, but it's packed with amazing attractions and experiences! Here's a list of popular sights and places to visit during your trip, categorized for convenience:
#
# ---
#
# ### **Iconic Landmarks & Attractions**
# 1. **Marina Bay Sands**
#    - Visit the famous SkyPark Observation Deck for fantastic views of the skyline.
#    - Explore the luxury shopping mall, restaurants, and even the infinity pool (only for hotel guests).
#
# 2. **Gardens by the Bay**
#    - Wander through the futuristic **Supertree Grove**.
#    - Explore the indoor attractions like the **Flower Dome** (world's largest glass greenhouse) and the **Cloud Forest** with its stunning waterfall.
#
# 3. **Merlion Park**
#    - Take a photo with Singapore's iconic half-lion, half-fish statue at Marina Bay.
#
# 4. **Singapore Flyer**
#    - Experience panoramic views of the city on one of the world’s largest observation wheels.
#
# ---
#
# ### **Historical & Cultural Spots**
# 5. **Chinatown**
#    - Visit the **Buddha Tooth Relic Temple**, explore street markets, and dine at small hawker stalls or restaurants serving traditional Chinese food.
#
# 6. **Little India**
#    - Check out the colorful **Sri Veeramakaliamman Temple** and enjoy authentic Indian cuisine.
#
# 7. **Kampong Glam**
#    - Explore the vibrant Arab Quarter with the stunning **Sultan Mosque**, boutique stores, and trendy cafes.
#
# 8. **National Museum of Singapore**
#    - Learn about Singapore's history, art, and heritage through interactive exhibits.
#
# ---
#
# ### **Nature & Wildlife**
# 9. **Singapore Botanic Gardens**
#    - A UNESCO World Heritage Site featuring lush greenery and the **National Orchid Garden**.
#
# 10. **Sentosa Island**
#    - Relax on sandy beaches, enjoy adventure activities, and visit **Universal Studios Singapore**. Other highlights include **Madame Tussauds**, **SEA Aquarium**, and **Adventure Cove Waterpark**.
#
# 11. **Singapore Zoo** & **Night Safari**
#    - One of the finest zoos globally, showcasing animals in open enclosures. Night Safari allows you to enjoy nocturnal wildlife.
#
# 12. **Pulau Ubin**
#    - A quaint island off Singapore that offers biking trails, kayaking, and a glimpse of traditional kampong (village) life.
#
# ---
#
# ### **Shopping & Entertainment**
# 13. **Orchard Road**
#    - Singapore's prime shopping district with high-end malls, boutique stores, and dining options.
#
# 14. **Bugis Street Market**
#    - A lively destination for budget-friendly shopping and street food.
#
# 15. **Clarke Quay and Boat Quay**
#    - Vibrant riverside spots with bars, clubs, restaurants, and river cruises.
#
# ---
#
# ### **Unique Experiences**
# 16. **Hawker Centers**
#    - Try local dishes like chicken rice, laksa, char kway teow, satay, and chili crab at places like Maxwell Food Centre, Lau Pa Sat, or Old Airport Road.
#
# 17. **Jewel Changi Airport**
#    - Even if you're just passing through, see the **Rain Vortex** (world’s largest indoor waterfall) and explore unique gardens and shops.
#
# ---
#
# ### Suggested Day Itineraries:
# - **Day 1:** Marina Bay Sands, Gardens by the Bay, Merlion Park.
# - **Day 2:** Sentosa Island or Zoo/Night Safari (nature-focused day).
# - **Day 3:** Chinatown, Little India, Kampong Glam for cultural exploration.
# - **Day 4:** Orchard Road, Bugis Market, Hawker center dining.
#
# Singapore is famous for its convenience and cleanliness, so getting around via public transportation (MRT and buses) is simple. Enjoy your trip! Let me know if you'd like detailed recommendations tailored to your interests.
# If you’re planning to explore Singapore in a day, you can still cover many highlights! Here’s a suggested **1-day itinerary** that focuses on iconic landmarks, cultural spots, and must-do experiences while keeping things manageable.
#
# ---
#
# ### **Morning: Marina Bay & Gardens by the Bay (Iconic Landmarks)**
# 1. **Merlion Park**
#    - Start your day with a visit to the iconic Merlion statue near Marina Bay. Snap some photos and enjoy the stunning views of Marina Bay Sands and the surrounding skyline.
#
# 2. **Marina Bay Sands & SkyPark Observation Deck**
#    - Head over to Marina Bay Sands and take the lift up to the SkyPark Observation Deck for panoramic views of Singapore. Check out the nearby luxury shopping mall or have breakfast at one of the cafes here.
#
# 3. **Gardens by the Bay**
#    - Walk across the **Helix Bridge** to reach **Gardens by the Bay**. Explore the **Supertree Grove** (free outdoor area) and, if time allows, visit indoor attractions like the **Cloud Forest** (featuring a stunning indoor waterfall) or the **Flower Dome**.
#
# ---
#
# ### **Lunch: Hawker Centers (Taste Singapore’s Food)**
# 4. **Chinatown: Maxwell Food Centre**
#    - Hop over to Chinatown and have lunch at **Maxwell Food Centre**, one of Singapore’s famous hawker centers. Try traditional dishes like **Chicken Rice**, **Char Kway Teow**, or **Laksa**—Singaporean classics.
#
# ---
#
# ### **Afternoon: Cultural Exploration**
# 5. **Chinatown**
#    - While you’re in Chinatown, explore the lively streets, souvenir shops, and visit the **Buddha Tooth Relic Temple**, which houses a golden chamber and offers insight into Singapore’s Buddhist heritage.
#
# 6. **Little India**
#    - Head over to **Little India** to explore the vibrant streets, colorful shophouses, and iconic **Sri Veeramakaliamman Temple**. You can also purchase unique souvenirs or enjoy a cup of teh tarik (frothy pulled tea).
#
# ---
#
# ### **Evening: Sentosa Island or Clarke Quay**
# 7. **Option 1: Sentosa Island**
#    - Take the cable car or train to **Sentosa Island** for a relaxed evening by the beach. You can visit the **SEA Aquarium**, take pictures at **Siloso Beach**, and enjoy dining at one of the island’s seaside restaurants.
#
# 8. **Option 2: Clarke Quay**
#    - If you're staying closer to central Singapore, head to **Clarke Quay**, the riverside dining and nightlife district. Enjoy dinner by the river and take a boat cruise for amazing views of Singapore lit up at night.
#
# ---
#
# ### **Bonus Night Stop: Gardens by the Bay Light Display**
# 9. **Garden Rhapsody Light & Sound Show** (if near Marina Bay Sands)
#    - Wrap up your day by returning to **Supertree Grove** at Gardens by the Bay for the light and sound show (free entry). This magical nightly display happens around 7:45 PM and 8:45 PM.
#
# ---
#
# ### **Quick Tips for the Day**
# - Use **MRT (subway)** to get around quickly and efficiently – it’s cheap, clean, and easy to navigate.
# - Wear comfortable walking shoes and light clothing since Singapore’s weather is typically warm and humid.
# - Stay hydrated as you’re likely to do a lot of walking outdoors.
#
# With this itinerary, you'll get to experience the best of Singapore’s highlights in one day!

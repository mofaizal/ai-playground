# %%
msg = "Let us build a simple multi module chatbot using the LLM library."
print(msg)
# Out:
# Let us build a simple multi module chatbot using the LLM library.

# %%
# !python -m venv labenv
# Activate the virtual environment
# %pip install --upgrade typing-extensions
# %pip install python-dotenv azure-identity azure-ai-projects azure-ai-inference
# Out:
# Requirement already satisfied: typing-extensions in c:\users\mofaizal\appdata\local\programs\python\python313\lib\site-packages (4.13.2)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: python-dotenv in c:\users\mofaizal\appdata\local\programs\python\python313\lib\site-packages (1.1.0)
# Requirement already satisfied: azure-identity in c:\users\mofaizal\appdata\local\programs\python\python313\lib\site-packages (1.21.0)
# Requirement already satisfied: azure-ai-projects in c:\users\mofaizal\appdata\local\programs\python\python313\lib\site-packages (1.0.0b10)
# Requirement already satisfied: azure-ai-inference in c:\users\mofaizal\appdata\local\programs\python\python313\lib\site-packages (1.0.0b9)
# Requirement already satisfied: azure-core>=1.31.0 in c:\users\mofaizal\appdata\local\programs\python\python313\lib\site-packages (from azure-identity) (1.33.0)
# Requirement already satisfied: cryptography>=2.5 in c:\users\mofaizal\appdata\local\programs\python\python313\lib\site-packages (from azure-identity) (44.0.2)
# Requirement already satisfied: msal>=1.30.0 in c:\users\mofaizal\appdata\local\programs\python\python313\lib\site-packages (from azure-identity) (1.32.3)
# Requirement already satisfied: msal-extensions>=1.2.0 in c:\users\mofaizal\appdata\local\programs\python\python313\lib\site-packages (from azure-identity) (1.3.1)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\mofaizal\appdata\local\programs\python\python313\lib\site-packages (from azure-identity) (4.13.2)
# Requirement already satisfied: isodate>=0.6.1 in c:\users\mofaizal\appdata\local\programs\python\python313\lib\site-packages (from azure-ai-projects) (0.7.2)
# Requirement already satisfied: requests>=2.21.0 in c:\users\mofaizal\appdata\local\programs\python\python313\lib\site-packages (from azure-core>=1.31.0->azure-identity) (2.32.3)
# Requirement already satisfied: six>=1.11.0 in c:\users\mofaizal\appdata\local\programs\python\python313\lib\site-packages (from azure-core>=1.31.0->azure-identity) (1.17.0)
# Requirement already satisfied: cffi>=1.12 in c:\users\mofaizal\appdata\local\programs\python\python313\lib\site-packages (from cryptography>=2.5->azure-identity) (1.17.1)
# Requirement already satisfied: pycparser in c:\users\mofaizal\appdata\local\programs\python\python313\lib\site-packages (from cffi>=1.12->cryptography>=2.5->azure-identity) (2.22)
# Requirement already satisfied: PyJWT<3,>=1.0.0 in c:\users\mofaizal\appdata\local\programs\python\python313\lib\site-packages (from PyJWT[crypto]<3,>=1.0.0->msal>=1.30.0->azure-identity) (2.10.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\mofaizal\appdata\local\programs\python\python313\lib\site-packages (from requests>=2.21.0->azure-core>=1.31.0->azure-identity) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\mofaizal\appdata\local\programs\python\python313\lib\site-packages (from requests>=2.21.0->azure-core>=1.31.0->azure-identity) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\mofaizal\appdata\local\programs\python\python313\lib\site-packages (from requests>=2.21.0->azure-core>=1.31.0->azure-identity) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\mofaizal\appdata\local\programs\python\python313\lib\site-packages (from requests>=2.21.0->azure-core>=1.31.0->azure-identity) (2025.4.26)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
from urllib.request import urlopen, Request
import base64

# Add references
from dotenv import load_dotenv
from azure.identity import DefaultAzureCredential
from azure.ai.projects import AIProjectClient
from azure.ai.inference.models import (
   SystemMessage,
   UserMessage,
   TextContentItem,
   ImageContentItem,
   ImageUrl,
   AudioContentItem,
   InputAudio,
   AudioContentFormat,
)

def main(): 

    # Clear the console
    os.system('cls' if os.name=='nt' else 'clear')
        
    try: 
    
        # Get configuration settings 
        load_dotenv()
        project_connection = os.getenv("PROJECT_CONNECTION")
        model_deployment =  os.getenv("MODEL_DEPLOYMENT")
        
        # Initialize the project client
        project_client = AIProjectClient.from_connection_string(
            conn_str=project_connection,
            credential=DefaultAzureCredential())
        

        ## Get a chat client
        chat_client = project_client.inference.get_chat_completions_client(model=model_deployment)

        system_message = "You are an AI assistent in a grocery store that sells fruit."
         

        # Loop until the user types 'quit'
        while True:
            input_text = input("Choose a prompt type (or type 'quit' to exit):\n-1: Text\n-2: Image\n-3: Audio\n")
            if input_text.lower() == "quit":
                break
            elif input_text == "1":
                prompt = input("Enter the prompt: ")
                if len(prompt) == 0:
                    print("Please enter a prompt.")
                else:
                    print("Getting a response to your prompt...")

                    # Get a response to text input
                    response = chat_client.complete(
                    messages=[
                        SystemMessage(system_message),
                        UserMessage(content=[TextContentItem(text= prompt)])
                    ])
                    print(response.choices[0].message.content)

            elif input_text == "2":
                prompt = input("Enter the prompt to accompany the image: ")
                if len(prompt) == 0:
                    print("Please enter a prompt.")
                else:
                    print("Getting a response to your prompt...")

                    # Get a response to image input
                    image_url = "https://raw.githubusercontent.com/mofaizal/al-playground/refs/heads/main/multimodal/01.jpg"
                    image_format = "jpeg"
                    request = Request(image_url, headers={"User-Agent": "Mozilla/5.0"})
                    image_data = base64.b64encode(urlopen(request).read()).decode("utf-8")
                    data_url = f"data:image/{image_format};base64,{image_data}"

                    response = chat_client.complete(
                    messages=[
                        SystemMessage(system_message),
                        UserMessage(content=[
                            TextContentItem(text=prompt),
                            ImageContentItem(image_url=ImageUrl(url=data_url))
                        ]),
                    ]
                    )
                    print(response.choices[0].message.content)

            elif input_text == "3":
                prompt = input("Enter the prompt to accompany an audio recording of 'Me gustaría comprar 2 manzanas.': ")
                if len(prompt) == 0:
                    print("Please enter a prompt.")
                else:
                    print("Getting a response to your prompt...")

                    # Get a response to audio input
                    file_path="https://raw.githubusercontent.com/mofaizal/al-playground/refs/heads/main/multimodal/manzanas.mp3"
                    response = chat_client.complete(
                        messages=[
                            SystemMessage(system_message),
                            UserMessage(
                                [
                                    TextContentItem(text=prompt),
                                    {
                                        "type": "audio_url",
                                        "audio_url": {"url": file_path}
                                    }
                                ]
                            )
                        ]
                    )
                    print(response.choices[0].message.content)

            else:
                print("Please enter a valid value")
                continue


    except Exception as ex:
        print(ex)


if __name__ == '__main__': 
    main()
# Out:
# Getting a response to your prompt...
# Hello, I would like to buy 2 apples.
